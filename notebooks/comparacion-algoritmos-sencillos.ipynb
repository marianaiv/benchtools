# %% [markdown]
# # Comparando algoritmos sencillos

# %% [markdown]
# ## Preparamos la data

# %%
# Importamos las librerias necesarias
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# Cargamos los dataframe con los datos pre-procesados

# %%
df_RD = pd.read_csv('../data/eventosRD_100000.csv')
df_bb = pd.read_csv('../data/eventosBB1_100000.csv')

# %%
# Definimos una función para separar un dataframe en caracteristicas y label
def data_ready(df, label='label'):
    
    # Creamos una lista con las características a considerar en el modelo
    carac_cols = df.columns.values.tolist()
    
    # Eliminamos 'label' porque no es una característica
    carac_cols.remove(label)
    carac_cols

    # Hacemos un dataframe solo con las características
    X = df[carac_cols]

    # Obtenemos la serie con la información sobre señal o fondo
    y = df[label]
    
    return X, y

# %% [markdown]
# Separamos la tabla en dos: una con las características y otra con los labels. Luego, creamos un conjunto de entrenamiento y uno de prueba

# %%
# Separamos los datos en conjuntos de entrenamiento y prueba
X_train, y_train = data_ready(df_RD)
X_test, y_test = data_ready(df_bb)

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% entrenamiento y 30% prueba

# %% [markdown]
# ## Clasificadores

# %%
# Importamos las métricas a utilizar
from sklearn.metrics import accuracy_score, log_loss, recall_score, plot_confusion_matrix,classification_report, f1_score

# Importamos los clasificadores
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# Para graficar
import matplotlib.pyplot as plt

# Listamos los clasificadores a comparar
classifiers = [
    LogisticRegression(max_iter=1000),
    KNeighborsClassifier(3),
    SVC(kernel="rbf", C=0.025, probability=False),
    #NuSVC(nu=0.3, probability=False),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis()]

# Registro para comparación visual
log_cols=["Classifier", "Accuracy", "Log Loss", "Recall score", "f1 score"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    
    # Entrenamos el clasificador y obtenemos su nombre
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    
    # Obtenemos las predicciones
    train_predictions = clf.predict(X_test)
    
    # Calculamos algunas métricas
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    ll = log_loss(y_test, train_predictions)
    print("Log Loss: {:.4}".format(ll))
    
    rs = recall_score(y_test, train_predictions)

    f1 = f1_score(y_test, train_predictions)
    
    # Imprimimos el reporte general
    print(classification_report(y_test, train_predictions, target_names=['fondo','señal']))
    
    # Insertamos los datos en el dataframe
    log_entry = pd.DataFrame([[name, acc*100, ll, rs, f1]], columns=log_cols)
    log = log.append(log_entry)
    
    # Graficamos la matriz de confusión
    disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=['fondo','senal'],
                                 cmap=plt.cm.Blues,
                                 normalize='true')
    
    disp.ax_.set_title("Confusion matrix for {}".format(name))

    plt.show()
    
print("="*30)
# Out:
# C:\Users\maria\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ==============================
# LogisticRegression
# ****Results****
# Accuracy: 94.8900%
# Log Loss: 1.765
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.95      0.97     99914
#        señal       0.01      0.67      0.02        86
#
#     accuracy                           0.95    100000
#    macro avg       0.51      0.81      0.50    100000
# weighted avg       1.00      0.95      0.97    100000
# ==============================
# KNeighborsClassifier
# ****Results****
# Accuracy: 96.8370%
# Log Loss: 1.092
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.97      0.98     99914
#        señal       0.00      0.09      0.01        86
#
#     accuracy                           0.97    100000
#    macro avg       0.50      0.53      0.49    100000
# weighted avg       1.00      0.97      0.98    100000
# ==============================
# SVC
# ****Results****
# Accuracy: 99.9140%
# Log Loss: 0.0297
# C:\Users\maria\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\maria\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\maria\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        fondo       1.00      1.00      1.00     99914
#        señal       0.00      0.00      0.00        86
#
#     accuracy                           1.00    100000
#    macro avg       0.50      0.50      0.50    100000
# weighted avg       1.00      1.00      1.00    100000
# ==============================
# DecisionTreeClassifier
# ****Results****
# Accuracy: 95.1080%
# Log Loss: 1.69
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.95      0.97     99914
#        señal       0.01      0.33      0.01        86
#
#     accuracy                           0.95    100000
#    macro avg       0.50      0.64      0.49    100000
# weighted avg       1.00      0.95      0.97    100000
# ==============================
# RandomForestClassifier
# ****Results****
# Accuracy: 99.0740%
# Log Loss: 0.3198
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.99      1.00     99914
#        señal       0.01      0.07      0.01        86
#
#     accuracy                           0.99    100000
#    macro avg       0.50      0.53      0.50    100000
# weighted avg       1.00      0.99      0.99    100000
# ==============================
# AdaBoostClassifier
# ****Results****
# Accuracy: 97.1660%
# Log Loss: 0.9789
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.97      0.99     99914
#        señal       0.02      0.56      0.03        86
#
#     accuracy                           0.97    100000
#    macro avg       0.51      0.77      0.51    100000
# weighted avg       1.00      0.97      0.98    100000
# ==============================
# GradientBoostingClassifier
# ****Results****
# Accuracy: 98.4630%
# Log Loss: 0.5309
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.99      0.99     99914
#        señal       0.03      0.47      0.05        86
#
#     accuracy                           0.98    100000
#    macro avg       0.51      0.73      0.52    100000
# weighted avg       1.00      0.98      0.99    100000
# ==============================
# GaussianNB
# ****Results****
# Accuracy: 90.2140%
# Log Loss: 3.38
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.90      0.95     99914
#        señal       0.01      0.83      0.01        86
#
#     accuracy                           0.90    100000
#    macro avg       0.50      0.86      0.48    100000
# weighted avg       1.00      0.90      0.95    100000
# ==============================
# LinearDiscriminantAnalysis
# ****Results****
# Accuracy: 92.6710%
# Log Loss: 2.531
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.93      0.96     99914
#        señal       0.01      0.74      0.02        86
#
#     accuracy                           0.93    100000
#    macro avg       0.50      0.84      0.49    100000
# weighted avg       1.00      0.93      0.96    100000
# C:\Users\maria\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:808: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# ==============================
# QuadraticDiscriminantAnalysis
# ****Results****
# Accuracy: 95.6880%
# Log Loss: 1.489
#               precision    recall  f1-score   support
#
#        fondo       1.00      0.96      0.98     99914
#        señal       0.01      0.71      0.03        86
#
#     accuracy                           0.96    100000
#    macro avg       0.51      0.83      0.50    100000
# weighted avg       1.00      0.96      0.98    100000
# ==============================

# %% [markdown]
# Hacemos plots comparando los valores obtenidos para cada algoritmo

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

sns.set_color_codes("muted")
sns.barplot(x='Log Loss', y='Classifier', data=log, color="g")

plt.xlabel('Log Loss')
plt.title('Classifier Log Loss')
plt.show()

sns.set_color_codes("muted")
sns.barplot(x='Recall score', y='Classifier', data=log, color="r")

plt.xlabel('Recall Score')
plt.title('Classifier Recall Score')
plt.show()

sns.set_color_codes("muted")
sns.barplot(x='f1 score', y='Classifier', data=log, color="y")

plt.xlabel('f1 Score')
plt.title('Classifier f1 Score')
plt.show()
